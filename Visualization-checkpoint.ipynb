# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt      
import math
import seaborn as sns
from collections import Counter
from sklearn.decomposition import PCA
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/final.csv')
df.columns
df.drop(columns={'name'},axis=1,inplace=True)
df
# Out:
#        games  gameStarted  minPlayed  fieldGoals  fieldGoalsAttemp  fGPerc  \
# 0        5.0          2.0       20.0         2.8               7.0   0.400
# 1       99.0         82.0       28.8         5.3              11.8   0.454
# 2      144.0        108.0       32.5         4.6              11.3   0.407
# 3       71.0         25.0       15.1         1.5               3.4   0.446
# 4       44.0          1.0        2.1         0.2               0.4   0.438
# ...      ...          ...        ...         ...               ...     ...
# 15412   62.0         49.0       27.8         4.6               9.6   0.477
# 15413  103.0         82.0       25.4         3.2               6.1   0.528
# 15414    5.0          0.0        2.4         0.2               0.4   0.500
# 15415   10.0          0.0        2.5         0.1               0.5   0.200
# 15416   17.0          9.0       20.9         0.6               1.5   0.400
#
# ...

# %%
plt.figure(figsize =(10,7))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.title("Connection between deffensive rebounds and number of field goals",fontdict={'fontname':'Tahoma','fontsize':20})
plt.xlabel('deffensRebounds')
plt.ylabel('fieldGoals')

plt.scatter(df.deffensRebounds, df.fieldGoals)

# %%
plt.title("Connection between offensive rebounds and number of 3 point goals",fontdict={'fontname':'Tahoma','fontsize':20})
plt.xlabel('offensRebounds')
plt.ylabel('point3_Goals')
plt.scatter(df.offensRebounds, df.point3_Goals)

# %%
df.columns
# Out:
# Index(['games', 'gameStarted', 'minPlayed', 'fieldGoals', 'fieldGoalsAttemp',
#        'fGPerc', 'point2_Goals', 'point2_Attemp', 'point2_Perc',
#        'point3_Goals', 'point3_Attemp', 'point3_Perc', 'freeThrows',
#        'freeThrowsAttemp', 'freeThrowsPerc', 'offensRebounds',
#        'deffensRebounds', 'draft'],
#       dtype='object')

# %%
plt.title("Connection between number of free throws attempts and field goals",fontdict={'fontname':'Tahoma','fontsize':20})
plt.xlabel('freeThrowsAttemp')
plt.ylabel('fieldGoals')
plt.scatter(df.freeThrowsAttemp, df.fieldGoals)
